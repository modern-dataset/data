# %%
''' Linear regression by using Deep Neural network: Implement Boston housing price prediction
problem by Linear regression using Deep Neural network. Use Boston House price prediction
dataset.'''
# Out:
# ' Linear regression by using Deep Neural network: Implement Boston housing price prediction\nproblem by Linear regression using Deep Neural network. Use Boston House price prediction\ndataset.'

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error

# %%
df = pd.read_csv('HousingData (1).csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90    NaN   36.2

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90    NaN   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99    NaN   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90    NaN   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99    NaN   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]>

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# PRICE      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# PRICE       0
# dtype: int64

# %%
df = df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
X = df.drop('PRICE',axis=1)
Y = df['PRICE']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
model = tf.keras.Sequential([

    tf.keras.layers.Dense(64,activation='relu',input_shape=(x_train.shape[1],)),
    tf.keras.layers.Dense(32,activation = 'relu'),
    tf.keras.layers.Dense(1),

    
]
)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
model.fit(x_train,y_train,epochs=100,batch_size=16,validation_split=0.2)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 599.6586 - mae: 22.5808 - val_loss: 509.0875 - val_mae: 20.9995
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 526.1622 - mae: 20.9751 - val_loss: 431.1234 - val_mae: 19.1755
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 424.2990 - mae: 18.5604 - val_loss: 315.7408 - val_mae: 16.1741
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 280.9923 - mae: 14.6582 - val_loss: 181.8291 - val_mae: 11.7876
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 148.7774 - mae: 10.0060 - val_loss: 84.6589 - val_mae: 7.1084
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 77.7946 - mae: 6.8243 - val_loss: 48.0414 - val_mae: 4.7502
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 50.6697 - mae: 5.2716 - val_loss: 34.5319 - val_mae: 3.9026
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 36.6831 - mae: 4.4142 - val_loss: 30.8680 - val_mae: 3.7052
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 30.6350 - mae: 4.0122 - val_loss: 28.8156 - val_mae: 3.7144
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 27.3641 - mae: 3.8278 - val_loss: 28.4815 - val_mae: 3.7426
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 25.4037 - mae: 3.6586 - val_loss: 28.2092 - val_mae: 3.7208
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 24.0984 - mae: 3.5608 - val_loss: 27.0004 - val_mae: 3.6452
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 22.6901 - mae: 3.4668 - val_loss: 26.4433 - val_mae: 3.5875
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.9447 - mae: 3.4118 - val_loss: 25.5495 - val_mae: 3.5393
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.7306 - mae: 3.2891 - val_loss: 24.8706 - val_mae: 3.4389
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 19.8230 - mae: 3.2213 - val_loss: 24.0091 - val_mae: 3.4115
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.0619 - mae: 3.1527 - val_loss: 23.4842 - val_mae: 3.3387
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.3312 - mae: 3.1046 - val_loss: 22.5733 - val_mae: 3.2868
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.6580 - mae: 3.0536 - val_loss: 22.2110 - val_mae: 3.2435
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.0830 - mae: 3.0048 - val_loss: 21.8551 - val_mae: 3.2265
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 16.5361 - mae: 2.9412 - val_loss: 21.6609 - val_mae: 3.2094
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 16.0526 - mae: 2.8811 - val_loss: 21.1831 - val_mae: 3.1783
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 15.6912 - mae: 2.8589 - val_loss: 20.9511 - val_mae: 3.1576
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 15.3429 - mae: 2.8394 - val_loss: 19.5432 - val_mae: 3.1026
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.8033 - mae: 2.7775 - val_loss: 19.8994 - val_mae: 3.1221
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.4880 - mae: 2.7594 - val_loss: 19.1899 - val_mae: 3.0663
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.0038 - mae: 2.7038 - val_loss: 19.4054 - val_mae: 3.0518
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 13.7079 - mae: 2.6582 - val_loss: 18.8372 - val_mae: 2.9982
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 13.4483 - mae: 2.6461 - val_loss: 18.5133 - val_mae: 2.9678
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 13.2791 - mae: 2.6445 - val_loss: 18.0071 - val_mae: 2.9406
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 13.0905 - mae: 2.6071 - val_loss: 18.0561 - val_mae: 2.9437
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.8317 - mae: 2.5733 - val_loss: 18.3871 - val_mae: 2.9690
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.6670 - mae: 2.5936 - val_loss: 18.1530 - val_mae: 2.9417
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.4298 - mae: 2.5523 - val_loss: 17.4514 - val_mae: 2.8779
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.2332 - mae: 2.5213 - val_loss: 17.7764 - val_mae: 2.9360
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.1231 - mae: 2.5326 - val_loss: 16.9870 - val_mae: 2.8310
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.1526 - mae: 2.5223 - val_loss: 17.2652 - val_mae: 2.8576
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.9901 - mae: 2.5444 - val_loss: 17.0066 - val_mae: 2.8617
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.7331 - mae: 2.4776 - val_loss: 17.5048 - val_mae: 2.8839
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.5589 - mae: 2.4679 - val_loss: 16.9037 - val_mae: 2.8823
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.3193 - mae: 2.4454 - val_loss: 16.9486 - val_mae: 2.8392
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 11.4265 - mae: 2.4435 - val_loss: 16.7501 - val_mae: 2.8570
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 11.1786 - mae: 2.4273 - val_loss: 17.0940 - val_mae: 2.8412
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10.9615 - mae: 2.4065 - val_loss: 16.4465 - val_mae: 2.8065
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10.9858 - mae: 2.4137 - val_loss: 16.4073 - val_mae: 2.8132
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 10.8059 - mae: 2.3917 - val_loss: 16.7371 - val_mae: 2.8255
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.6055 - mae: 2.3676 - val_loss: 16.2513 - val_mae: 2.8011
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 10.6972 - mae: 2.3845 - val_loss: 16.2478 - val_mae: 2.8044
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.5591 - mae: 2.3683 - val_loss: 16.4135 - val_mae: 2.7969
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 10.5631 - mae: 2.3784 - val_loss: 15.8016 - val_mae: 2.7661
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.4493 - mae: 2.3426 - val_loss: 16.5140 - val_mae: 2.8200
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10.3718 - mae: 2.3464 - val_loss: 15.8338 - val_mae: 2.7393
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 10.4183 - mae: 2.3817 - val_loss: 15.4896 - val_mae: 2.7117
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10.1372 - mae: 2.3065 - val_loss: 16.3461 - val_mae: 2.8082
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10.5102 - mae: 2.3690 - val_loss: 15.4196 - val_mae: 2.7848
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.2002 - mae: 2.3098 - val_loss: 15.8537 - val_mae: 2.7778
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.8983 - mae: 2.3132 - val_loss: 14.9056 - val_mae: 2.7346
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.8262 - mae: 2.2834 - val_loss: 15.2874 - val_mae: 2.7565
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.7676 - mae: 2.2758 - val_loss: 14.6018 - val_mae: 2.7147
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.7416 - mae: 2.2927 - val_loss: 15.3887 - val_mae: 2.7736
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.6282 - mae: 2.2569 - val_loss: 15.0357 - val_mae: 2.7428
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4383 - mae: 2.2668 - val_loss: 15.3467 - val_mae: 2.7468
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.2998 - mae: 2.2411 - val_loss: 14.8759 - val_mae: 2.6958
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.2954 - mae: 2.2285 - val_loss: 14.9487 - val_mae: 2.7253
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2012 - mae: 2.2180 - val_loss: 14.9888 - val_mae: 2.7463
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1435 - mae: 2.2283 - val_loss: 14.7851 - val_mae: 2.7079
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1385 - mae: 2.2349 - val_loss: 14.7221 - val_mae: 2.7264
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.9847 - mae: 2.2055 - val_loss: 14.4821 - val_mae: 2.6837
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.9872 - mae: 2.2015 - val_loss: 14.4123 - val_mae: 2.6954
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8413 - mae: 2.1769 - val_loss: 14.7257 - val_mae: 2.6960
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.8998 - mae: 2.2041 - val_loss: 14.1426 - val_mae: 2.6417
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.6556 - mae: 2.1631 - val_loss: 14.2492 - val_mae: 2.6633
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.6124 - mae: 2.1568 - val_loss: 14.4886 - val_mae: 2.6947
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.5946 - mae: 2.1500 - val_loss: 14.3555 - val_mae: 2.6912
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4476 - mae: 2.1369 - val_loss: 14.0576 - val_mae: 2.6842
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.4566 - mae: 2.1365 - val_loss: 13.5265 - val_mae: 2.6266
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.4799 - mae: 2.1316 - val_loss: 13.7080 - val_mae: 2.6498
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.2771 - mae: 2.1123 - val_loss: 14.1755 - val_mae: 2.6913
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.2569 - mae: 2.1046 - val_loss: 14.3392 - val_mae: 2.7015
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.2265 - mae: 2.1092 - val_loss: 14.2773 - val_mae: 2.7009
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.1472 - mae: 2.0971 - val_loss: 14.4693 - val_mae: 2.7498
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.1318 - mae: 2.1161 - val_loss: 13.4592 - val_mae: 2.6113
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.1429 - mae: 2.0764 - val_loss: 14.5477 - val_mae: 2.7615
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.2539 - mae: 2.1486 - val_loss: 13.1126 - val_mae: 2.5647
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.1627 - mae: 2.0889 - val_loss: 14.6098 - val_mae: 2.7824
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9987 - mae: 2.0932 - val_loss: 13.3318 - val_mae: 2.6012
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.7413 - mae: 2.0540 - val_loss: 14.4278 - val_mae: 2.7415
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7505 - mae: 2.0482 - val_loss: 13.2160 - val_mae: 2.5989
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.8990 - mae: 2.0766 - val_loss: 13.5905 - val_mae: 2.6594
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8055 - mae: 2.0792 - val_loss: 13.5224 - val_mae: 2.6488
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6483 - mae: 2.0334 - val_loss: 13.3994 - val_mae: 2.6400
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.5044 - mae: 2.0149 - val_loss: 13.5368 - val_mae: 2.6608
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.9241 - mae: 2.0859 - val_loss: 13.5636 - val_mae: 2.6628
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.6893 - mae: 2.0349 - val_loss: 13.0905 - val_mae: 2.6307
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4437 - mae: 2.0049 - val_loss: 13.8674 - val_mae: 2.7169
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.4906 - mae: 2.0172 - val_loss: 13.4019 - val_mae: 2.6529
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.3129 - mae: 1.9977 - val_loss: 12.6410 - val_mae: 2.5907
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.3659 - mae: 1.9893 - val_loss: 12.7251 - val_mae: 2.6045
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.1260 - mae: 1.9675 - val_loss: 13.0684 - val_mae: 2.6264
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.1400 - mae: 1.9650 - val_loss: 12.9584 - val_mae: 2.6125

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MSE: 19.899644391192094
# R2 Score: 0.7286428773531659
